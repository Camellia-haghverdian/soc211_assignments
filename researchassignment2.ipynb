// %% [markdown]
// ## Research assignment 2
//
// Camellia Haghverdian
//
// Do age, income, and years of education have an impact on people's opinion on death penalty?
//
// 02/12/2024

// %% [markdown]
// ### 1. Write a paragraph about your hypotheses
//
// [Your answer here should explain:
// 1. My dependent variable is cappun (favor or oppose death penalty for murder). I was interested to see what factors have an impact on people's opinion when it comes to death penalty for murder given that it is such a controversial topic these days.
// 2. My independent variables are age, degree (last degree earned), educ (last year of schooling completed), knwmw1 (gender), rincome (income), year, and ballot. Among all the independent variables, I think income has a positive impact on people favoring or opposing death penalty for murder, meaning richer people are more in favor of death penalty, but that more educated people are against it.
// 3. I assume that people with more money have more power and would always like to be in charge of big decisions such as death penalty to create the societal landscape they desire. On the contrary, more levels of education make people aware of the ineffectiveness of death penalty and they usually go against it.
// 4. Education, degree, age, income, and gender are my control variables, and especially education, degree, and income have interactive realtionships with opinions on death penalty. They interact both with each other and with opinions on death penalty. Changes in one will probably yield different results each time.

// %% [markdown]
// ### 1. Setting up your session
//
// In the code cell below, do the following:
//
// 1. set current directory
// 2. set more off
// 3. create log file
// 4. download the data from its source if it's available online
// 5. read the data in [preferably only variables you are going to use]

// %%
cd "/Users/camellia/Documents/Stats 2/soc211_assignments"
// Out:
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>
// /Users/camellia/Documents/Stats 2/soc211_assignments

// %%
set more off
// Out:
// (-set more- irrelevant in this version of Stata)

// %%
log using "Log for Research Assignment 2.log", replace
// Out:
// (file /Users/camellia/Documents/Stats 2/soc211_assignments/Log for Research
//     Assignment 2.log not found)
// -------------------------------------------------------------------------------
//       name:  <unnamed>
//        log:  /Users/camellia/Documents/Stats 2/soc211_assignments/Log for Resea
// > rch Assignment 2.log
//   log type:  text
//  opened on:  12 Feb 2024, 15:06:23

// %%
set maxvar 100000

// %%
use "/Users/camellia/Documents/Stats 2/soc211_assignments/GSS_stata 2/gss7222_r2.dta", clear

// %% [markdown]
// ### 2. Browse the data
// Do the following in separate cells. Do do these in separate cells, you will need to use the right click "split cell" option:
//
// 1. Use "describe" to print details about the dataset
// 2. Print the heads and tables of the data using the appropriate magic
// 3. label the unique identifier variable
// 4. Generate a frequency table to show the N for each unit of time if there is data for multiple units in time
// 5. Check for missing data overall and within key categories of analysis (time, independent or dependent variable categories, etc)
// 6. use summarize to create a table with summary statistics for each variable you plan to analyze

// %%
describe id year ballot cappun rincome age knwmw1 degree educ
// Out:
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// -------------------------------------------------------------------------------
// id              int     %8.0g                 Respodent's ID Number
// year            int     %29.0g     COUNTMISS
//                                               gss year for this respondent
// ballot          byte    %29.0g     BALLOT     ballot used for interview
// cappun          byte    %29.0g     FAVOROPPOSE
//                                               favor or oppose death penalty for
//                                                 murder
// rincome         byte    %29.0g     INCOME     respondents income
// age             byte    %29.0g     AGE        age of respondent
// knwmw1          byte    %29.0g     GENDER2F   gender identity of person 1
// degree          byte    %29.0g     DEGREE     r's highest degree
// ...

// %%
codebook id year ballot cappun rincome age knwmw1 degree educ
// Out:
// -------------------------------------------------------------------------------
// id                                                        Respodent's ID Number
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (int)
//
//                  Range: [1,4510]                      Units: 1
//          Unique values: 4,510                     Missing .: 0/72,390
//
//                   Mean:  1241.8
//              Std. dev.: 912.273
//
//            Percentiles:     10%       25%       50%       75%       90%
//                             214       534      1083      1722      2533
//
// -------------------------------------------------------------------------------
// year                                               gss year for this respondent
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (int)
// ...

// %%
label variable id "Respodent's ID Number"

// %%
tab year, missing
tab ballot, missing
tab cappun, missing
tab knwmw1, missing
tab degree, missing
sum rincome
sum age
sum educ
// Out:
//  gss year for this respondent |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
//                          1972 |      1,613        2.23        2.23
//                          1973 |      1,504        2.08        4.31
//                          1974 |      1,484        2.05        6.36
//                          1975 |      1,490        2.06        8.41
//                          1976 |      1,499        2.07       10.48
//                          1977 |      1,530        2.11       12.60
//                          1978 |      1,532        2.12       14.71
//                          1980 |      1,468        2.03       16.74
//                          1982 |      1,860        2.57       19.31
//                          1983 |      1,599        2.21       21.52
//                          1984 |      1,473        2.03       23.56
//                          1985 |      1,534        2.12       25.67
// ...

// %% [markdown]
// ### 3. Write a note summarizing what you learned from browsing the data
//
// This data is cross-sectional data. It covers information from 1972 to 2022, and it contains 21,875 missing data out of 72,390 for ballot (which is a significant number), 11,543 for cappun (in favor of or oppose death penalty), 30,057 for rincome (income), 769 for age, 71,795 for knwmw1 (gender), 196 for degree (highest degree earned), and 263 for educ (highest year of school completed). Cappun, knwmw1, and degree are categorical variables whereas rincome, age, and educ are nominal variables.
// My dependent variable, cappun (in favor of or oppose death penalty) is categorical and its mode is 42,181.

// %% [markdown]
// ### 4. Create univariate histograms of interval ratio variables you plan to analyze.
//
// Write at least 3 forloops to generate histograms for all the variables you plan to analyze. Create titles for each histogram that notes whether it is a dependent, independent, or control variable (you can also note in titles whether control vars control for spurious, intervening, or interactive relationships). Begin with your dependent variables. Then make a note below to describe the shapes of the distributions and their implications for your study.
//
// - The age histogram is skewed. It shows people aged between 25-35 have a higher frequency in this dataset. Older people are less present in the dataset and the reason to why that happens could be important to investigate. I think age has an interactive relationship with opinions on death penalty. Younger people tend to be more opinionated when it comes to this matter.
// - The income histogram is skewed as well. It illustrates the majority of family income variable to be at about 12 (maybe 1200?). I'm not sure what that signifies if it signifies anything at all, but I think the relationship with opinions on death penalty is again interactive. The graph shows that people with a lot of money do exist in the dataset but that whether or not that correlates with pro-death penalty opinions is unclear.
// - And according to educ (years of schooling completed), majority of participants have a frequency of roughly 12 years of schooling and the almost similar shape of a bell curve shows an even distribution. Therefore, most people present in this study are high school graduates and after that perhaps undergraduates with approximately 16 years of schooling. I think years of schooling has an intervening relationship with opinions on death penalty, in that more education might mean fewer pro-death penalty opinions?! I'm still not sure if I'm able to conclude that.

// %%
histogram age, frequency title("Age (Control for Interaction with income)")
// Out:
// (bin=48, start=18, width=1.4791667)

// %%
histogram income, frequency title("Income (Control for Interaction with age)")
// Out:
// (bin=48, start=1, width=.22916667)

// %%
histogram educ, frequency title("Years of Schooling (Control for Intervening with age)")
// Out:
// (bin=48, start=0, width=.41666667)

// %% [markdown]
// ### 5. Create univariate count and % frequency tables for all categorical (nominal) variables you plan to analyze
//
// Again, use forloops. Then write a note below with a narrative summary of the distributions and their implications for your study.
//
// - Among ballots, Ballot D is noticeable in that it has the least frequency (1,518) compared to the rest of the ballots. Ballots A, B, and C are pretty similar to each other in terms of distribution.
// - Among 'favor or oppose death penalty for murder', 42,181 respondents are in favor of death penalty, which is an exciting piece of information on its own.
// - On gender, there are more females (321) than males (272). In Iran, mothers are usually a part of the vulnerable population who vote for death penalty as they are scared of criminals hurting their children. I know Iran doesn't exist in this dataset, but maybe motherhood has a role in all of this?
// - Among degrees, the highest frequency belongs to 36,446 respondents who have high school education, followed by 14,192 respondents who have less that high school education, and then bachelor holders who consist 11,248 of the respondents. This shows the average of highest degree earned belongs to hig hschool graduates, and not necessarily more educated people such as undergraduates or graduates.

// %%
foreach x of varlist ballot cappun knwmw1 degree {
    replace `x'=. if `x'==.i | `x'==.n | `x'==.d | `x'==.s
    tab `x', missing
}
// Out:
// (0 real changes made)
//
//     ballot used for interview |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
//                      ballot a |     16,239       22.43       22.43
//                      ballot b |     16,477       22.76       45.19
//                      ballot c |     16,281       22.49       67.68
//                      ballot d |      1,518        2.10       69.78
//                             . |     21,875       30.22      100.00
// ------------------------------+-----------------------------------
//                         Total |     72,390      100.00
// (70 real changes made, 70 to missing)
//
// favor or oppose death penalty |
//                    for murder |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
//                         favor |     42,181       58.27       58.27
// ...

// %% [markdown]
// ### 6. Make a relevant bivariate table and graph for your study
//
// Make the appropriate a) bivariate table and b) graph dependening on whether your dependent variable is nominal/categorical or interval ratio. If your dependent variable is nominal, make sure it is the row variable in the table. If your independent variable is interval ratio, convert it into an ordinal variable by creating a new variable with 3 to 5 categories each with an equal range of the interval ratio variable. Then use the new ordinal variable as your independent variable in the bivariate table and graph.

// %%
codebook cappun
// Out:
// -------------------------------------------------------------------------------
// cappun                                 favor or oppose death penalty for murder
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: FAVOROPPOSE
//
//                  Range: [1,2]                         Units: 1
//          Unique values: 2                         Missing .: 11,543/72,390
//
//             Tabulation: Freq.   Numeric  Label
//                        42,181         1  favor
//                        18,666         2  oppose
//                        11,543         .

// %%
gen pro_death=cappun
replace pro_death=0 if cappun==2

label variable pro_death "does the respondent support the death penalty"
label define pro_death 0 "no" 1 "yes"
label values pro_death pro_death

codebook pro_death
// Out:
// (11,543 missing values generated)
// (18,666 real changes made)
//
// -------------------------------------------------------------------------------
// pro_death                         does the respondent support the death penalty
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (float)
//                  Label: pro_death
//
//                  Range: [0,1]                         Units: 1
//          Unique values: 2                         Missing .: 11,543/72,390
//
//             Tabulation: Freq.   Numeric  Label
//                        18,666         0  no
//                        42,181         1  yes
//                        11,543         .

// %%
graph hbar (mean) pro_death, over(rincome) title("Views on Death Penalty and Income")

// %% [markdown]
// ### 7. Create partial bivariate tables and graphs
//
// For the bivariate table and graph you made for problem 6, split both into partial tables and graphs using one of your nominal/categorical control variables. If your control variable is interval ratio, convert it into an ordinal variable by creating a variable with 3 to 5 categories each with an equal range of the interval ratio variable.  Then use the new ordinal variable as your control variable to create the partial tables and graphs.

// %%
graph hbar (mean) pro_death if degree==0, over(rincome) by(degree) title("People Pro-Death Penalty by Income: Less than HS")

// %%
graph hbar (mean) pro_death if degree==1, over(rincome) by(degree) title("People Pro-Death Penalty by Income: HS Degree")

// %%
graph hbar (mean) pro_death if degree==2, over(rincome) by(degree) title("People Pro-Death Penalty by Income: Associate/junior college")

// %%
graph hbar (mean) pro_death if degree==3, over(rincome) by(degree) title("People Pro-Death Penalty by Income: Bachelor's")

// %%
graph hbar (mean) pro_death if degree==4, over(rincome) by(degree) title("People Pro-Death Penalty by Income: Graduate")

// %%
codebook degree
// Out:
// -------------------------------------------------------------------------------
// degree                                                       r's highest degree
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: DEGREE
//
//                  Range: [0,4]                         Units: 1
//          Unique values: 5                         Missing .: 196/72,390
//
//             Tabulation: Freq.   Numeric  Label
//                        14,192         0  less than high school
//                        36,446         1  high school
//                         4,355         2  associate/junior college
//                        11,248         3  bachelor's
//                         5,953         4  graduate
//                           196         .

// %% [markdown]
// ### Interpret of your bivariate and partial tables and graphs
//
// Is there a relationship between your dependent and independent variables? Is it weak, strong, or non-existent? Do adding controls reveal any spurious, intervening, or interactive relationships? Do they conform with your hypotheses? If not, do you have any ideas for why and how you might test the reason why?
//
// - Unfortunately, there is not a significant relationship between income and being in favor of death penalty for murder. However, two things caught my attention. The last graph shows that the majority of graduate students earning under $1000 are more in favor of death penalty. And it's only among high school graduates that steady increase in income also corresponds with more opinions favoring death penalty. However, the relationships don't seem to be very meaningful either in that or the rest of the graphs.
// - I don't think any spurious, intervening, or interactive relationships are present among these variables.
// - My hypothesis is denied! :-(
// - Perhaps other variables like country of origin or specific world events and years should be considered in this research to yield more meaningful relationships. The country of origin and the type of government could reveal a lot about a country's punitive system and people's tolerance of crimes like murder. But I couldn't find these variables on GSS and had to work with the variables that were available. If income and education have no impact on people's opinions on death penalty, does that mean we have reached to a universal agreement that death penalty is bad and that it should be abolished?!?!?!
